# %%
import matplotlib.pyplot as plt
import numpy as np
from parse_log import parse_log

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
log_path = "../log/train001.log"
train_dict_list, test_dict_list = parse_log(log_path)
iter_list = []
loss_list = []
for each in train_dict_list:
    iter_list.append(each["NumIters"])
    loss_list.append(each["loss"])
iter_arr = np.array(iter_list)
loss_arr = np.array(loss_list)
plt.plot(iter_arr, loss_arr)
plt.show()

# %%
log_path = "../log/train00001.log"
train_dict_list, test_dict_list = parse_log(log_path)
iter_list = []
loss_list = []
for each in train_dict_list:
    iter_list.append(each["NumIters"])
    loss_list.append(each["loss"])
iter_arr = np.array(iter_list)
loss_arr = np.array(loss_list)
plt.plot(iter_arr, loss_arr)
plt.show()

# %%
log_path = "../log/train0000001.log"
train_dict_list, test_dict_list = parse_log(log_path)
iter_list = []
loss_list = []
for each in train_dict_list:
    iter_list.append(each["NumIters"])
    loss_list.append(each["loss"])
iter_arr = np.array(iter_list)
loss_arr = np.array(loss_list)
plt.plot(iter_arr, loss_arr)
plt.show()

# %%
log_path = "../log/train_with_lstm/train000000001.log"
train_dict_list, test_dict_list = parse_log(log_path)
iter_list = []
loss_list = []
for each in train_dict_list:
    iter_list.append(each["NumIters"])
    loss_list.append(each["loss"])
iter_arr = np.array(iter_list)
loss_arr = np.array(loss_list)
plt.plot(iter_arr, loss_arr)
plt.show()
